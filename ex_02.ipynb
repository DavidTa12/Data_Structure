# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pad

# %%
df = pad.read_csv('data.csv')
data.head(10)
# Out:
#    year                    reg_name                                  tax_name  \
# 0  2013  Provence-Alpes-Côte d'Azur                       Charges financières
# 1  2013  Provence-Alpes-Côte d'Azur                                      CVAE
# 2  2013  Provence-Alpes-Côte d'Azur                        Frais de personnel
# 3  2013  Provence-Alpes-Côte d'Azur                           Impôts et taxes
# 4  2013  Provence-Alpes-Côte d'Azur                 Recettes d'investissement
# 5  2013  Provence-Alpes-Côte d'Azur      Subventions reçues et participations
# 6  2013                   Normandie           Autres dotations et subventions
# 7  2013                   Normandie          Autres recettes d'investissement
# 8  2013                   Normandie                          Dépôts au Trésor
# 9  2013                   Normandie  Subventions aux personnes de droit privé
#
#          amount
# 0  6.709871e+07
# 1  2.580641e+08
# 2  2.302554e+08
# 3  9.147599e+08
# 4  3.356027e+08
# ...

# %%
table = pad.pivot_table(df, columns=['tax_name'],index=['reg_name', 'year'], aggfunc='sum')
pad.set_option('display.max_rows', None)
display(table)
# Out:
#                                                     amount                  \
# tax_name                        Achats et charges externes Allocations APA
# reg_name                   year
# Auvergne-Rhône-Alpes       2012               1.793130e+08             NaN
#                            2013               1.865618e+08             NaN
#                            2014               1.848917e+08             NaN
#                            2015               1.909913e+08             NaN
#                            2016               1.687399e+08             NaN
#                            2017               1.431209e+08             NaN
#                            2018               1.710875e+08             NaN
#                            2019               1.713981e+08             NaN
# Bourgogne-Franche-Comté    2012               6.927123e+07             NaN
#                            2013               6.347728e+07             NaN
# ...
